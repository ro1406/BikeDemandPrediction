# %% [markdown]
# # Explore + Fix Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("/bike_sharing_demand_prediction_ai_challenge_-dataset/TRAIN.csv",index_col=0)

# %%
data.head()
# Out:
#              Date  Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# Index
# 0      01/12/2017     0             -5.2           37               2.2
# 1      01/12/2017     1             -5.5           38               0.8
# 2      01/12/2017     2             -6.0           39               1.0
# 3      01/12/2017     3             -6.2           40               0.9
# 4      01/12/2017     4             -6.0           36               2.3
#
#        Visibility (10m)  Dew point temperature(°C)  Solar Radiation (MJ/m2)  \
# Index
# 0                  2000                      -17.6                      0.0
# 1                  2000                      -17.6                      0.0
# 2                  2000                      -17.7                      0.0
# 3                  2000                      -17.6                      0.0
# 4                  2000                      -18.6                      0.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7031
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       7032 non-null   object
#  1   Hour                       7032 non-null   int64
#  2   Temperature(°C)            7032 non-null   float64
#  3   Humidity(%)                7032 non-null   int64
#  4   Wind speed (m/s)           7032 non-null   float64
#  5   Visibility (10m)           7032 non-null   int64
#  6   Dew point temperature(°C)  7032 non-null   float64
#  7   Solar Radiation (MJ/m2)    7032 non-null   float64
#  8   Rainfall(mm)               7032 non-null   float64
#  9   Snowfall (cm)              7032 non-null   float64
#  10  Seasons                    7032 non-null   object
#  11  Holiday                    7032 non-null   object
#  12  Functioning Day            7032 non-null   object
# ...

# %%
data.describe()
# Out:
#               Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# count  7032.000000      7032.000000  7032.000000       7032.000000
# mean     11.500000        13.154778    58.164960          1.785708
# std       6.922679        12.997927    20.637447          1.053112
# min       0.000000       -17.800000     0.000000          0.000000
# 25%       5.750000         1.800000    42.000000          1.000000
# 50%      11.500000        15.500000    57.000000          1.600000
# 75%      17.250000        24.000000    74.000000          2.400000
# max      23.000000        39.400000    98.000000          7.400000
#
#        Visibility (10m)  Dew point temperature(°C)  Solar Radiation (MJ/m2)  \
# count       7032.000000                7032.000000              7032.000000
# mean        1421.082480                   4.323905                 0.590294
# std          613.169137                  14.178857                 0.893909
# ...

# %%
data.isna().sum()
# Out:
# Date                         0
# Hour                         0
# Temperature(°C)              0
# Humidity(%)                  0
# Wind speed (m/s)             0
# Visibility (10m)             0
# Dew point temperature(°C)    0
# Solar Radiation (MJ/m2)      0
# Rainfall(mm)                 0
# Snowfall (cm)                0
# Seasons                      0
# Holiday                      0
# Functioning Day              0
# Rented Bike Count            0
# dtype: int64

# %%
sns.boxplot(x=data['Seasons'],y=data['Rented Bike Count'])

# %%
sns.boxplot(x=data['Holiday'],y=data['Rented Bike Count'])

# %%
sns.boxplot(x=data['Functioning Day'],y=data['Rented Bike Count'])

# %%
szns=pd.get_dummies(data['Seasons'])
holi=pd.get_dummies(data['Holiday'])
funcday=pd.get_dummies(data['Functioning Day'],prefix="Func ")

# %%
data.drop(["Seasons","Holiday","Functioning Day"],axis=1,inplace=True)

# %%
data=pd.concat([data,szns,holi,funcday],axis=1)

# %%
data.head()
# Out:
#              Date  Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  \
# Index
# 0      01/12/2017     0             -5.2           37               2.2
# 1      01/12/2017     1             -5.5           38               0.8
# 2      01/12/2017     2             -6.0           39               1.0
# 3      01/12/2017     3             -6.2           40               0.9
# 4      01/12/2017     4             -6.0           36               2.3
#
#        Visibility (10m)  Dew point temperature(°C)  Solar Radiation (MJ/m2)  \
# Index
# 0                  2000                      -17.6                      0.0
# 1                  2000                      -17.6                      0.0
# 2                  2000                      -17.7                      0.0
# 3                  2000                      -17.6                      0.0
# 4                  2000                      -18.6                      0.0
#
# ...

# %%
data.drop("Date",axis=1,inplace=True)

# %%
data.head()
# Out:
#        Hour  Temperature(°C)  Humidity(%)  Wind speed (m/s)  Visibility (10m)  \
# Index
# 0         0             -5.2           37               2.2              2000
# 1         1             -5.5           38               0.8              2000
# 2         2             -6.0           39               1.0              2000
# 3         3             -6.2           40               0.9              2000
# 4         4             -6.0           36               2.3              2000
#
#        Dew point temperature(°C)  Solar Radiation (MJ/m2)  Rainfall(mm)  \
# Index
# 0                          -17.6                      0.0           0.0
# 1                          -17.6                      0.0           0.0
# 2                          -17.7                      0.0           0.0
# 3                          -17.6                      0.0           0.0
# 4                          -18.6                      0.0           0.0
#
# ...

# %%
data.to_csv("/bike_sharing_demand_prediction_ai_challenge_-dataset/Cleaned.csv")

# %%
plt.figure(figsize=(12,10))
sns.heatmap(data.corr(),cmap='coolwarm',annot=True)

# %%
sns.jointplot(x=data['Temperature(°C)'], y=data['Rented Bike Count'])
